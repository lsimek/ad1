# %% [markdown]
# tinjano@github, Feb 2024
#
# This notebook is part of the repository at https://github.com/tinjano/ad1.
#
# This notebook collects data about Google advertising using BigQuery. The data is found in `creative_stats` and `removed_creative_stats` (data about ads that were removed by Google) tables, part of the `google_ads_transparency_ceneter` dataset of the `bigquery-public-data` project. In particular, we collect all data about advertisements that were shown in Croatia with all data already available (for some entries, data will become available at a set date in the future; see schemes below).
#
# To run this or a similar notebook, you will need to have the credentials for a Google Cloud service account with adequate permissions. Be careful about potentially processing very large amount of data.

# %% [markdown]
# # Imports

# %%
# Python standard utilities
import os
os.makedirs('data/', exist_ok=True)
from pprint import pprint as pretty_print
from datetime import datetime

# data processing
import pandas as pd

# google
from google.cloud import bigquery
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'google-credentials.json'

# auxiliary modules
from aux import country_to_abbrev, abbrev_to_country

# config
project = 'bigquery-public-data'
dataset = 'google_ads_transparency_center'

# %% [markdown]
# # Tables and Schemes

# %%
client = bigquery.Client()

dataset_ref = client.dataset(dataset, project=project)
dataset_ = client.get_dataset(dataset_ref)

for table_ in list(client.list_tables(dataset_)):
    id_ = table_.table_id
    if '-temp-' in id_:
        continue
        
    print(f'\x1b[31mTable id: {table_.table_id}\x1b[0m')
    table = client.get_table('.'.join([project, dataset, table_.table_id]))
    pretty_print(vars(table).get('_properties').get('schema'))
    print('\n')
# Out:
# Table id: creative_stats
# {'fields': [{'description': 'A unique identifier for a specific advertiser',
#              'mode': 'NULLABLE',
#              'name': 'advertiser_id',
#              'type': 'STRING'},
#             {'description': 'A unique identifier for a specific ad',
#              'mode': 'NULLABLE',
#              'name': 'creative_id',
#              'type': 'STRING'},
#             {'description': 'A link to the relevant Ads Transparency Center '
#                             'page for this ad',
#              'mode': 'NULLABLE',
#              'name': 'creative_page_url',
#              'type': 'STRING'},
#             {'description': 'A description of the ad type',
#              'mode': 'NULLABLE',
#              'name': 'ad_format_type',
#              'type': 'STRING'},
#             {'description': "The advertiser's name for transparency reporting "
#                             'and disclosures',
#              'mode': 'NULLABLE',
#              'name': 'advertiser_disclosed_name',
#              'type': 'STRING'},
#             {'description': 'The legal name of the advertiser',
#              'mode': 'NULLABLE',
#              'name': 'advertiser_legal_name',
#              'type': 'STRING'},
#             {'description': 'ISO 3166-2 region code (for example "FR" for '
#                             'France)',
#              'mode': 'NULLABLE',
#              'name': 'advertiser_location',
#              'type': 'STRING'},
#             {'description': 'Whether or not the advertiser has verified their '
#                             'identity with Google yet',
#              'mode': 'NULLABLE',
#              'name': 'advertiser_verification_status',
#              'type': 'STRING'},
#             {'description': 'Collection of regions in which the ad served (in '
#                             'the European Economic Area and Turkey) and their '
#                             'relevant stats',
#              'fields': [{'description': 'ISO 3166-2 region code (for example '
#                                         '"FR" for France) of the region where '
#                                         'the ad was shown, or a text '
#                                         'representation of an aggregate region '
#                                         '(for example "EEA" for the European '
#                                         'Economic Area)',
#                          'mode': 'NULLABLE',
#                          'name': 'region_code',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the '
#                                         'first date the ad was shown. If the '
#                                         'ad was first shown before March 1st, '
#                                         '2023, March 1st, 2023 will be '
#                                         'reported as the first_shown date.',
#                          'mode': 'NULLABLE',
#                          'name': 'first_shown',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the last '
#                                         'date the ad was shown',
#                          'mode': 'NULLABLE',
#                          'name': 'last_shown',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the date '
#                                         'up to which times_shown (both upper '
#                                         'and lower bounds) has been updated. '
#                                         'This field is NULL if no impressions '
#                                         'occurred within the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_end_date',
#                          'type': 'STRING'},
#                         {'description': 'The lower bound of the number of '
#                                         'times the ad was shown in the '
#                                         'associated region. This field is NULL '
#                                         'if no impressions occurred within the '
#                                         'reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_lower_bound',
#                          'type': 'INTEGER'},
#                         {'description': 'The upper bound of the number of '
#                                         'times the ad was shown in the '
#                                         'associated region. This field is NULL '
#                                         'if no impressions occurred within the '
#                                         'valid reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_upper_bound',
#                          'type': 'INTEGER'},
#                         {'description': 'YYYY-MM-DD representation of the '
#                                         'earliest date for which times_shown '
#                                         'is considered (both upper and lower '
#                                         'bounds). Impressions are reported for '
#                                         'activity since March 1st, 2023. This '
#                                         'field is NULL if no impressions '
#                                         'occurred with the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_start_date',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the date '
#                                         'on which impressions will become '
#                                         'available if no impressions occurred '
#                                         'within the reporting period. This '
#                                         'field is NULL if impressions did '
#                                         'occur within the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_availability_date',
#                          'type': 'STRING'},
#                         {'description': 'Collection of surface which the ad '
#                                         'served in and their relevant serving '
#                                         'times lower/upper bound.',
#                          'fields': [{'fields': [{'mode': 'NULLABLE',
#                                                  'name': 'surface',
#                                                  'type': 'STRING'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_upper_bound',
#                                                  'type': 'INTEGER'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_lower_bound',
#                                                  'type': 'INTEGER'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_availability_date',
#                                                  'type': 'STRING'}],
#                                      'mode': 'REPEATED',
#                                      'name': 'surface_serving_stats',
#                                      'type': 'RECORD'}],
#                          'mode': 'NULLABLE',
#                          'name': 'surface_serving_stats',
#                          'type': 'RECORD'}],
#              'mode': 'REPEATED',
#              'name': 'region_stats',
#              'type': 'RECORD'},
#             {'description': 'Information on audience selection, broken out by '
#                             'approach type. The available values are: '
#                             '"CRITERIA_INCLUDED" (Criteria from this category '
#                             "were included in the ad's audience), "
#                             '"CRITERIA_EXCLUDED" (Criteria from this category '
#                             "were excluded from the ad's audience), "
#                             '"CRITERIA_INCLUDED_AND_EXCLUDED" (Some criteria '
#                             'from this category were included and others were '
#                             "excluded from the ad's audience), and "
#                             '"CRITERIA_UNUSED" (Criteria from these categories '
#                             'were not used for audience selection).',
#              'fields': [{'description': 'Describes if and how demographic info '
#                                         'was used to select the ad audience '
#                                         '(see audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'demographic_info',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how geo location '
#                                         'info was used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'geo_location',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how contextual '
#                                         'signals were used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'contextual_signals',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how customer lists '
#                                         'were used to select the ad audience '
#                                         '(see audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'customer_lists',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how topics of '
#                                         'interest were used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'topics_of_interest',
#                          'type': 'STRING'}],
#              'mode': 'NULLABLE',
#              'name': 'audience_selection_approach_info',
#              'type': 'RECORD'},
#             {'description': 'The topic of the ad',
#              'mode': 'NULLABLE',
#              'name': 'topic',
#              'type': 'STRING'}]}
#
#
# Table id: removed_creative_stats
# {'fields': [{'description': 'A link to the removed Ads Transparency Center '
#                             'page for this ad',
#              'mode': 'NULLABLE',
#              'name': 'creative_page_url',
#              'type': 'STRING'},
#             {'description': 'Collection of regions in which the ad served (in '
#                             'the European Economic Area) and their relevant '
#                             'stats',
#              'fields': [{'description': 'ISO 3166-2 region code (for example '
#                                         '"FR" for France) of the region where '
#                                         'the ad was shown, or a text '
#                                         'representation of an aggregate region '
#                                         '(for example "EEA" for the European '
#                                         'Economic Area)',
#                          'mode': 'NULLABLE',
#                          'name': 'region_code',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the '
#                                         'first date the ad was shown. If the '
#                                         'ad was first shown before March 1st, '
#                                         '2023, March 1st, 2023 will be '
#                                         'reported as the first_shown date.',
#                          'mode': 'NULLABLE',
#                          'name': 'first_shown',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the last '
#                                         'date the ad was shown',
#                          'mode': 'NULLABLE',
#                          'name': 'last_shown',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the date '
#                                         'up to which times_shown (both upper '
#                                         'and lower bounds) has been updated. '
#                                         'This field is NULL if no impressions '
#                                         'occurred within the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_end_date',
#                          'type': 'STRING'},
#                         {'description': 'The lower bound of the number of '
#                                         'times the ad was shown in the '
#                                         'associated region. This field is NULL '
#                                         'if no impressions occurred within the '
#                                         'reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_lower_bound',
#                          'type': 'INTEGER'},
#                         {'description': 'The upper bound of the number of '
#                                         'times the ad was shown in the '
#                                         'associated region. This field is NULL '
#                                         'if no impressions occurred within the '
#                                         'valid reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_upper_bound',
#                          'type': 'INTEGER'},
#                         {'description': 'YYYY-MM-DD representation of the '
#                                         'earliest date for which times_shown '
#                                         'is considered (both upper and lower '
#                                         'bounds). Impressions are reported for '
#                                         'activity since March 1st, 2023. This '
#                                         'field is NULL if no impressions '
#                                         'occurred with the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_start_date',
#                          'type': 'STRING'},
#                         {'description': 'YYYY-MM-DD representation of the date '
#                                         'on which impressions will become '
#                                         'available if no impressions occurred '
#                                         'within the reporting period. This '
#                                         'field is NULL if impressions did '
#                                         'occur within the reporting period.',
#                          'mode': 'NULLABLE',
#                          'name': 'times_shown_availability_date',
#                          'type': 'STRING'},
#                         {'description': 'Collection of surface which the ad '
#                                         'served in and their relevant serving '
#                                         'times lower/upper bound.',
#                          'fields': [{'fields': [{'mode': 'NULLABLE',
#                                                  'name': 'surface',
#                                                  'type': 'STRING'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_upper_bound',
#                                                  'type': 'INTEGER'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_lower_bound',
#                                                  'type': 'INTEGER'},
#                                                 {'mode': 'NULLABLE',
#                                                  'name': 'times_shown_availability_date',
#                                                  'type': 'STRING'}],
#                                      'mode': 'REPEATED',
#                                      'name': 'surface_serving_stats',
#                                      'type': 'RECORD'}],
#                          'mode': 'NULLABLE',
#                          'name': 'surface_serving_stats',
#                          'type': 'RECORD'}],
#              'mode': 'REPEATED',
#              'name': 'region_stats',
#              'type': 'RECORD'},
#             {'description': 'Information on audience selection, broken out by '
#                             'approach type. The available values are: '
#                             '"CRITERIA_INCLUDED" (Criteria from this category '
#                             "were included in the ad's audience), "
#                             '"CRITERIA_EXCLUDED" (Criteria from this category '
#                             "were excluded from the ad's audience), "
#                             '"CRITERIA_INCLUDED_AND_EXCLUDED" (Some criteria '
#                             'from this category were included and others were '
#                             "excluded from the ad's audience), and "
#                             '"CRITERIA_UNUSED" (Criteria from these categories '
#                             'were not used for audience selection).',
#              'fields': [{'description': 'Describes if and how demographic info '
#                                         'was used to select the ad audience '
#                                         '(see audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'demographic_info',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how geo location '
#                                         'info was used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'geo_location',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how contextual '
#                                         'signals were used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'contextual_signals',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how customer lists '
#                                         'were used to select the ad audience '
#                                         '(see audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'customer_lists',
#                          'type': 'STRING'},
#                         {'description': 'Describes if and how topics of '
#                                         'interest were used to select the ad '
#                                         'audience (see '
#                                         'audience_selection_approach_info '
#                                         'above for more details)',
#                          'mode': 'NULLABLE',
#                          'name': 'topics_of_interest',
#                          'type': 'STRING'}],
#              'mode': 'NULLABLE',
#              'name': 'audience_selection_approach_info',
#              'type': 'RECORD'},
#             {'description': 'Information on how, where, and why the ad was '
#                             'removed',
#              'fields': [{'description': 'The policy/policies that the ad '
#                                         'violated',
#                          'mode': 'NULLABLE',
#                          'name': 'removal_reason',
#                          'type': 'STRING'},
#                         {'description': 'The high level policy violation '
#                                         'category',
#                          'mode': 'NULLABLE',
#                          'name': 'violation_category',
#                          'type': 'STRING'},
#                         {'description': 'Populated if the review of the ad was '
#                                         'automated',
#                          'mode': 'NULLABLE',
#                          'name': 'use_of_automated_means',
#                          'type': 'BOOLEAN'},
#                         {'description': 'ISO 3166-2 region code (for example '
#                                         '"FR" for France) of the region where '
#                                         'the ad was removed, or "GLOBAL" if '
#                                         'the ad was removed globally',
#                          'mode': 'REPEATED',
#                          'name': 'removal_location',
#                          'type': 'STRING'},
#                         {'description': 'Whether the investigation was a '
#                                         'result of a Google investigation or a '
#                                         'legal notice',
#                          'mode': 'NULLABLE',
#                          'name': 'decision_type',
#                          'type': 'STRING'}],
#              'mode': 'REPEATED',
#              'name': 'disapproval',
#              'type': 'RECORD'}]}

# %% [markdown]
# # `creative_stats` table

# %% [markdown]
# ## Query

# %%
table = 'creative_stats'
print('.'.join([project, dataset, table]))
# Out:
# bigquery-public-data.google_ads_transparency_center.creative_stats

# %%
query_job = client.query(
    f'''
    SELECT
    creative_page_url,
    ad_format_type,
    advertiser_disclosed_name,
    advertiser_location,
    advertiser_verification_status,
    
    PARSE_TIMESTAMP('%Y-%m-%d', first_shown) AS first_shown,
    PARSE_TIMESTAMP('%Y-%m-%d', last_shown) AS last_shown,
    PARSE_TIMESTAMP('%Y-%m-%d', times_shown_end_date) AS  times_shown_end_date,
    
    times_shown_lower_bound AS times_shown_lower,
    times_shown_upper_bound AS times_shown_upper,
    
    IF(audience_selection_approach_info.demographic_info = 'CRITERIA_UNUSED',  0,  1) AS selection_demographic,
    IF(audience_selection_approach_info.geo_location = 'CRITERIA_UNUSED',  0,  1) AS selection_geo,
    IF(audience_selection_approach_info.contextual_signals = 'CRITERIA_UNUSED',  0,  1) AS selection_contextual,
    IF(audience_selection_approach_info.customer_lists = 'CRITERIA_UNUSED',  0,  1) AS selection_customer_lists,
    IF(audience_selection_approach_info.topics_of_interest = 'CRITERIA_UNUSED',  0,  1) AS selection_toi,

    topic
    
    
    FROM `{'.'.join([project, dataset, table])}`,
        UNNEST(region_stats)

    WHERE
    region_code='HR' AND
    times_shown_availability_date IS NULL
    '''
)

# %%
print('Starting time: ', datetime.now())
# %time df = query_job.to_dataframe()
# Out:
# Starting time:  2024-02-15 07:25:34.950907
# CPU times: user 1min 4s, sys: 2.98 s, total: 1min 7s
# Wall time: 15min 52s

# %% [markdown]
# ## Cleaning

# %%
df.advertiser_location = df.advertiser_location.apply(lambda x: abbrev_to_country.get(x.strip('\"')))

# %%
for col in ['ad_format_type', 'advertiser_verification_status', 'topic']:
    df.loc[:, col] = df.loc[:, col].str.lower()

# %%
df['days_running'] = (df.last_shown - df.first_shown).dt.days

# %%
df = df.astype({
    'ad_format_type': 'category',
    'advertiser_location': 'category',
    'advertiser_verification_status': 'category',
    'selection_demographic': 'boolean',
    'selection_geo': 'boolean',
    'selection_contextual': 'boolean',
    'selection_customer_lists': 'boolean',
    'selection_toi': 'boolean',
    'topic': 'category'
})

# %%
df.shape, df.dtypes
# Out:
# ((3154151, 17),
#  creative_page_url                              object
#  ad_format_type                               category
#  advertiser_disclosed_name                      object
#  advertiser_location                          category
#  advertiser_verification_status               category
#  first_shown                       datetime64[us, UTC]
#  last_shown                        datetime64[us, UTC]
#  times_shown_end_date              datetime64[us, UTC]
#  times_shown_lower                               Int64
#  times_shown_upper                               Int64
#  selection_demographic                         boolean
#  selection_geo                                 boolean
#  selection_contextual                          boolean
#  selection_customer_lists                      boolean
#  selection_toi                                 boolean
#  topic                                        category
#  days_running                                    int64
#  dtype: object)

# %%
df
# Out:
#                                          creative_page_url ad_format_type  \
# 0        https://adstransparency.google.com/advertiser/...           text
# 1        https://adstransparency.google.com/advertiser/...           text
# 2        https://adstransparency.google.com/advertiser/...           text
# 3        https://adstransparency.google.com/advertiser/...           text
# 4        https://adstransparency.google.com/advertiser/...           text
# ...                                                    ...            ...
# 3154146  https://adstransparency.google.com/advertiser/...           text
# 3154147  https://adstransparency.google.com/advertiser/...          video
# 3154148  https://adstransparency.google.com/advertiser/...          video
# 3154149  https://adstransparency.google.com/advertiser/...          video
# 3154150  https://adstransparency.google.com/advertiser/...          video
#
#                 advertiser_disclosed_name  advertiser_location  \
# 0              Zauchensee Walchhofer GmbH              Austria
# 1                        ALLESkralle GmbH              Austria
# 2                     AutoScout24 AS GmbH              Austria
# 3                 Donau-Universität Krems              Austria
# 4                 Harry's Home Holding AG              Austria
# ...                                   ...                  ...
# 3154146      wagner andres alvarez tejeda        United States
# 3154147                    ABI GLOBAL LTD  Virgin Islands (UK)
# 3154148  INFINITY TECHNOLOGIES GLOBAL LTD  Virgin Islands (UK)
# 3154149                    VTN GLOBAL LTD  Virgin Islands (UK)
# 3154150                          Quang Vu              Vietnam
#
#         advertiser_verification_status               first_shown  \
# 0                           unverified 2023-03-01 00:00:00+00:00
# 1                             verified 2023-03-01 00:00:00+00:00
# 2                             verified 2023-03-01 00:00:00+00:00
# 3                             verified 2023-03-20 00:00:00+00:00
# 4                             verified 2023-09-06 00:00:00+00:00
# ...                                ...                       ...
# 3154146                       verified 2023-07-04 00:00:00+00:00
# 3154147                       verified 2023-03-01 00:00:00+00:00
# 3154148                       verified 2023-07-28 00:00:00+00:00
# 3154149                       verified 2023-11-15 00:00:00+00:00
# 3154150                       verified 2023-11-03 00:00:00+00:00
#
#                        last_shown      times_shown_end_date  \
# 0       2024-02-13 00:00:00+00:00 2023-11-16 00:00:00+00:00
# 1       2023-10-28 00:00:00+00:00 2023-10-28 00:00:00+00:00
# 2       2023-12-03 00:00:00+00:00 2023-11-16 00:00:00+00:00
# 3       2024-01-02 00:00:00+00:00 2023-11-16 00:00:00+00:00
# 4       2024-02-13 00:00:00+00:00 2023-11-16 00:00:00+00:00
# ...                           ...                       ...
# 3154146 2024-02-07 00:00:00+00:00 2023-11-16 00:00:00+00:00
# 3154147 2023-09-15 00:00:00+00:00 2023-09-15 00:00:00+00:00
# 3154148 2023-08-06 00:00:00+00:00 2023-08-06 00:00:00+00:00
# 3154149 2023-11-26 00:00:00+00:00 2023-11-16 00:00:00+00:00
# 3154150 2024-02-11 00:00:00+00:00 2023-11-16 00:00:00+00:00
#
#          times_shown_lower  times_shown_upper  selection_demographic  \
# 0                        0               1000                   True
# 1                        0               1000                   True
# 2                        0               1000                   True
# 3                        0               1000                   True
# 4                        0               1000                   True
# ...                    ...                ...                    ...
# 3154146                  0               1000                   True
# 3154147               1000               2000                   True
# 3154148                  0               1000                   True
# 3154149                  0               1000                   True
# 3154150                  0               1000                   True
#
#          selection_geo  selection_contextual  selection_customer_lists  \
# 0                 True                  True                     False
# 1                 True                  True                     False
# 2                 True                  True                      True
# 3                 True                  True                     False
# 4                 True                  True                     False
# ...                ...                   ...                       ...
# 3154146           True                  True                     False
# 3154147           True                  True                     False
# 3154148          False                  True                     False
# 3154149           True                  True                     False
# 3154150           True                  True                     False
#
#          selection_toi                     topic  days_running
# 0                False          travel & tourism           349
# 1                False          jobs & education           241
# 2                False          autos & vehicles           277
# 3                False          jobs & education           288
# 4                False          travel & tourism           160
# ...                ...                       ...           ...
# 3154146          False          travel & tourism           218
# 3154147          False  hobbies, games & leisure           198
# 3154148          False  hobbies, games & leisure             9
# 3154149          False        family & community            11
# 3154150          False  hobbies, games & leisure           100
#
# [3154151 rows x 17 columns]

# %% [markdown]
# ## Save to disk

# %%
df.to_parquet('data/google-ads-hr-2.parquet')

# %% [markdown]
# # `removed_creative_stats`

# %% [markdown]
# ## Query

# %%
table = 'removed_creative_stats'
print('.'.join([project, dataset, table]))
# Out:
# bigquery-public-data.google_ads_transparency_center.removed_creative_stats

# %%
query_job = client.query(
    f'''
    SELECT
    creative_page_url,
    PARSE_TIMESTAMP('%Y-%m-%d', first_shown) AS first_shown,
    PARSE_TIMESTAMP('%Y-%m-%d', last_shown) AS last_shown,
    PARSE_TIMESTAMP('%Y-%m-%d', times_shown_end_date) AS  times_shown_end_date,
    times_shown_lower_bound AS times_shown_lower,
    times_shown_upper_bound AS times_shown_upper,

    IF(audience_selection_approach_info.demographic_info = 'CRITERIA_UNUSED',  0,  1) AS selection_demographic,
    IF(audience_selection_approach_info.geo_location = 'CRITERIA_UNUSED',  0,  1) AS selection_geo,
    IF(audience_selection_approach_info.contextual_signals = 'CRITERIA_UNUSED',  0,  1) AS selection_contextual,
    IF(audience_selection_approach_info.customer_lists = 'CRITERIA_UNUSED',  0,  1) AS selection_customer_lists,
    IF(audience_selection_approach_info.topics_of_interest = 'CRITERIA_UNUSED',  0,  1) AS selection_toi,

    disapproval[0].removal_reason AS removal_reason,
    disapproval[0].violation_category AS violation_category,
    disapproval[0].use_of_automated_means AS automated,
    disapproval[0].decision_type AS decision_type,


    FROM `{'.'.join([project, dataset, table])}`,
        UNNEST(region_stats)

    WHERE
    region_code='HR' AND
    times_shown_availability_date IS NULL
    '''
)

# %%
print('Starting time: ', datetime.now())
# %time df_removed = query_job.to_dataframe()
# Out:
# Starting time:  2024-02-15 07:41:47.504215
# CPU times: user 1.52 s, sys: 145 ms, total: 1.67 s
# Wall time: 19 s

# %% [markdown]
# ## Cleaning

# %%
df_removed.removal_reason = df_removed.removal_reason.str.lower()

# %%
df_removed.violation_category = (df_removed.violation_category
                                 .str.split('_')
                                 .apply(lambda x: list(map(str.lower, x)))
                                 .str.join(' '))

# %%
df_removed['days_running'] = (df_removed.last_shown - df_removed.first_shown).dt.days

# %%
df_removed = df_removed.astype({
    'selection_demographic': 'boolean',
    'selection_geo': 'boolean',
    'selection_contextual': 'boolean',
    'selection_customer_lists': 'boolean',
    'selection_toi': 'boolean',

    'removal_reason': 'category',
    'violation_category': 'category',
    'automated': 'boolean',
    'decision_type': 'category'
})

# %%
df_removed.shape, df_removed.dtypes
# Out:
# ((86363, 16),
#  creative_page_url                        object
#  first_shown                 datetime64[us, UTC]
#  last_shown                  datetime64[us, UTC]
#  times_shown_end_date        datetime64[us, UTC]
#  times_shown_lower                         Int64
#  times_shown_upper                         Int64
#  selection_demographic                   boolean
#  selection_geo                           boolean
#  selection_contextual                    boolean
#  selection_customer_lists                boolean
#  selection_toi                           boolean
#  removal_reason                         category
#  violation_category                     category
#  automated                               boolean
#  decision_type                          category
#  days_running                              int64
#  dtype: object)

# %%
df_removed
# Out:
#                                        creative_page_url  \
# 0      https://adstransparency.google.com/removed/cre...
# 1      https://adstransparency.google.com/removed/cre...
# 2      https://adstransparency.google.com/removed/cre...
# 3      https://adstransparency.google.com/removed/cre...
# 4      https://adstransparency.google.com/removed/cre...
# ...                                                  ...
# 86358  https://adstransparency.google.com/removed/cre...
# 86359  https://adstransparency.google.com/removed/cre...
# 86360  https://adstransparency.google.com/removed/cre...
# 86361  https://adstransparency.google.com/removed/cre...
# 86362  https://adstransparency.google.com/removed/cre...
#
#                     first_shown                last_shown  \
# 0     2023-09-01 00:00:00+00:00 2023-10-24 00:00:00+00:00
# 1     2023-09-16 00:00:00+00:00 2023-09-20 00:00:00+00:00
# 2     2023-11-08 00:00:00+00:00 2023-12-03 00:00:00+00:00
# 3     2023-03-23 00:00:00+00:00 2024-01-23 00:00:00+00:00
# 4     2023-08-09 00:00:00+00:00 2023-09-03 00:00:00+00:00
# ...                         ...                       ...
# 86358 2023-08-15 00:00:00+00:00 2023-11-30 00:00:00+00:00
# 86359 2023-06-13 00:00:00+00:00 2023-08-13 00:00:00+00:00
# 86360 2023-08-30 00:00:00+00:00 2023-11-05 00:00:00+00:00
# 86361 2023-10-03 00:00:00+00:00 2023-10-03 00:00:00+00:00
# 86362 2023-06-23 00:00:00+00:00 2023-11-21 00:00:00+00:00
#
#            times_shown_end_date  times_shown_lower  times_shown_upper  \
# 0     2023-10-24 00:00:00+00:00                  0               1000
# 1     2023-09-20 00:00:00+00:00               9000              10000
# 2     2023-11-16 00:00:00+00:00                  0               1000
# 3     2023-11-16 00:00:00+00:00                  0               1000
# 4     2023-09-03 00:00:00+00:00                  0               1000
# ...                         ...                ...                ...
# 86358 2023-11-16 00:00:00+00:00                  0               1000
# 86359 2023-08-13 00:00:00+00:00              50000              60000
# 86360 2023-11-05 00:00:00+00:00                  0               1000
# 86361 2023-10-03 00:00:00+00:00                  0               1000
# 86362 2023-11-16 00:00:00+00:00                  0               1000
#
#        selection_demographic  selection_geo  selection_contextual  \
# 0                       True           True                  True
# 1                       True           True                  True
# 2                       True           True                  True
# 3                       True           True                  True
# 4                       True           True                  True
# ...                      ...            ...                   ...
# 86358                  False           True                  True
# 86359                  False           True                  True
# 86360                  False           True                  True
# 86361                  False           True                  True
# 86362                  False          False                  True
#
#        selection_customer_lists  selection_toi            removal_reason  \
# 0                         False           True                 editorial
# 1                          True          False                 editorial
# 2                         False           True         misrepresentation
# 3                         False          False  healthcare and medicines
# 4                         False          False        account suspension
# ...                         ...            ...                       ...
# 86358                     False          False        account suspension
# 86359                     False          False                 editorial
# 86360                     False          False        account suspension
# 86361                      True          False                trademarks
# 86362                     False          False     inappropriate content
#
#                     violation_category  automated         decision_type  \
# 0              editorial and technical      False  Google investigation
# 1              editorial and technical      False  Google investigation
# 2                 prohibited practices      False  Google investigation
# 3      restricted content and features       True  Google investigation
# 4                 prohibited practices      False  Google investigation
# ...                                ...        ...                   ...
# 86358             prohibited practices      False  Google investigation
# 86359          editorial and technical      False  Google investigation
# 86360             prohibited practices      False  Google investigation
# 86361  restricted content and features      False  Google investigation
# 86362               prohibited content       True  Google investigation
#
#        days_running
# 0                53
# 1                 4
# 2                25
# 3               306
# 4                25
# ...             ...
# 86358           107
# 86359            61
# 86360            67
# 86361             0
# 86362           151
#
# [86363 rows x 16 columns]

# %% [markdown]
# ## Save to disk

# %%
df_removed.to_parquet('data/google-ads-hr-removed-2.parquet')

# %% [markdown]
# # Problems in the data
# Note that the `times_shown_upper` column (`times_shown_upper_bound` in the original tables) contains instances of an extremely large number (2^64 - 1), either as the result of an error or as a way to signal that there is no upper bound.

# %%
df.times_shown_upper.value_counts()
# Out:
# times_shown_upper
# 1000                   2756478
# 2000                    129188
# 3000                     54392
# 4000                     31782
# 15000                    22619
# 5000                     21307
# 6000                     15682
# 20000                    13236
# 7000                     12154
# 8000                      9616
# 25000                     8843
# 9000                      8002
# 30000                     6674
# 10000                     6623
# 35000                     4988
# 60000                     4577
# 40000                     4136
# 125000                    3852
# 70000                     3610
# 45000                     3373
# 150000                    2798
# 80000                     2788
# 50000                     2751
# 90000                     2344
# 175000                    2152
# 100000                    2061
# 300000                    1842
# 200000                    1679
# 225000                    1406
# 350000                    1340
# 250000                    1161
# 600000                    1109
# 400000                    1102
# 450000                     896
# 700000                     866
# 1250000                    790
# 500000                     771
# 800000                     636
# 1500000                    565
# 900000                     532
# 1000000                    481
# 1750000                    421
# 2000000                    368
# 3000000                    308
# 2250000                    292
# 9223372036854775807        262
# 3500000                    232
# 2500000                    226
# 4000000                    176
# 6000000                    137
# 4500000                    121
# 7000000                    110
# 5000000                     98
# 8000000                     94
# 9000000                     62
# 10000000                    42
# Name: count, dtype: Int64

# %%
df_removed.times_shown_upper.value_counts()
# Out:
# times_shown_upper
# 1000                   74537
# 2000                    3494
# 3000                    1623
# 4000                     868
# 15000                    690
# 5000                     587
# 20000                    452
# 6000                     378
# 7000                     339
# 25000                    331
# 30000                    271
# 8000                     268
# 10000                    208
# 9000                     196
# 35000                    187
# 60000                    150
# 125000                   142
# 40000                    139
# 45000                    125
# 70000                    118
# 50000                    104
# 80000                     85
# 175000                    83
# 150000                    81
# 300000                    76
# 90000                     75
# 100000                    72
# 350000                    69
# 225000                    63
# 200000                    57
# 600000                    54
# 250000                    54
# 400000                    48
# 500000                    44
# 700000                    42
# 450000                    38
# 1250000                   31
# 1500000                   29
# 900000                    25
# 800000                    22
# 2000000                   19
# 1000000                   18
# 1750000                   16
# 3000000                   12
# 2250000                   11
# 4000000                    7
# 2500000                    4
# 7000000                    4
# 5000000                    3
# 6000000                    3
# 9223372036854775807        3
# 3500000                    2
# 8000000                    2
# 9000000                    2
# 4500000                    2
# Name: count, dtype: Int64
